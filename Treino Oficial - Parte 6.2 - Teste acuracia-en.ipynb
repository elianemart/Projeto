# %%
import gensim
import codecs
import numpy as np
import time
from sklearn.metrics.pairwise import cosine_similarity

path = '/home/lili/Desktop/Projeto/treino/acuracia/'
alpha1 = 10**(-16)
alpha3 = 10**(-11)

# %%
modelpt = gensim.models.Word2Vec.load(path + 'model-english')

f = codecs.open(path + 'adj-adv-en.txt', encoding = 'utf-8', mode = 'w')

# %%
h = codecs.open(path + 'adj-adv-en.txt', encoding = 'utf-8', mode = 'r')

test = h.read().split()

f.write('adj-adv')
f.write('\n')

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c0d3f17e33a0> in <module>()
#      51
#      52     try:
# ---> 53         if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
#      54             c8 = c8 + 1
#      55     except KeyError:
#
# /usr/local/lib/python2.7/dist-packages/gensim-0.12.3-py2.7-linux-x86_64.egg/gensim/models/word2vec.pyc in most_similar(self, positive, negative, topn, restrict_vocab)
#    1178
#    1179         limited = self.syn0norm if restrict_vocab is None else self.syn0norm[:restrict_vocab]
# -> 1180         dists = dot(limited, mean)
#    1181         if not topn:
#    1182             return dists
#
# KeyboardInterrupt:

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')
# Out:
# [u'atenas', u'gr\xe9cia', u'bagd\xe1', u'iraque'] 2024

# %%
h2 = codecs.open(path + 'capital-world-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()

f.write('\n')
f.write('capital-world')
f.write('\n')

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12
# Out:
# 4524 711 1 0 0 0 540 1125 1162 569 0 0 1 1

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')
# Out:
# síria

# %%
h2 = codecs.open(path + 'city-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()

print test[0:5]
test[0] = u'chicago'

f.write('\n')
f.write('city')
f.write('\n')
# Out:
# [u'\ufeffchicago', u'illinois', u'houston', u'texas', u'chicago']

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12
# Out:
# 2467 2676 6 0 0 0 69 281 300 69 2 0 8 0

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')

# %%
h2 = codecs.open(path + 'comparativo-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()

f.write('\n')
f.write('comparativo')
f.write('\n')

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')
# Out:
# 237

# %%
h2 = codecs.open(path + 'currency-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()

f.write('\n')
f.write('currency')
f.write('\n')

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12
# Out:
# 866 0 1 1 0 0 7 9 9 7 0 0 1 1

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')

# %%
h2 = codecs.open(path + 'family-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()

f.write('\n')
f.write('familia')
f.write('\n')

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12
# Out:
# 992 9 0 0 7 7 45 39 39 45 3 3 0 0

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')
# Out:
# 4524

# %%
h2 = codecs.open(path + 'nacio-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()

f.write('\n')
f.write('nacionalidade')
f.write('\n')
# Out:
# [u'arg\xe9lia', u'dinar', u'angola', u'kwanza']

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')

# %%
h2 = codecs.open(path + 'oposto-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()
f.write('\n')
f.write('opostos')
f.write('\n')

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')

# %%
h2 = codecs.open(path + 'pais-capital-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()
f.write('\n')
f.write('pais-capital')
f.write('\n')

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')

# %%
h2 = codecs.open(path + 'past-tense-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()

f.write('\n')
f.write('past-tense')
f.write('\n')

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')

# %%
h2 = codecs.open(path + 'plural-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()

f.write('\n')
f.write('plural')
f.write('\n')

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')

# %%
h2 = codecs.open(path + 'plural-verbo-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()

f.write('\n')
f.write('plural-verbo')
f.write('\n')

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')

# %%
h2 = codecs.open(path + 'present-en.txt', encoding = 'utf-8', mode = 'r')
test = h2.read().split()

f.write('\n')
f.write('present')
f.write('\n')

# %%
c1 =c2 = c3 = c4 =c5 = c6 = c7 = c8 = c9 = c10 = c11 = c12 = 0
t = len(test)/4
erros = 0

for i in range(t):
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i +3]:
            c1 = c1 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 1]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 2]:
            c2 = c2 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 3]:
            c3 = c3 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i + 1]:
            c4 = c4 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i + 2]:
            c5 = c5 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i + 1]:
            c6 = c6 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 3]:
            c7 = c7 + 1

    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 2]], negative=[test[4*i + 3]], topn=1)[0][0] == test[4*i]:
            c8 = c8 + 1
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 2]:
            c9 = c9 + 1
            
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 1], test[4*i + 3]], negative=[test[4*i + 2]], topn=1)[0][0] == test[4*i]:
           c10 = c10 + 1
        
    except KeyError:
        erros = erros + 1
    
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i]], topn=1)[0][0] == test[4*i + 1]:
            c11 = c11 + 1
    except KeyError:
        erros = erros + 1
        
    try:
        if modelpt.most_similar(positive=[test[4*i + 2], test[4*i + 3]], negative=[test[4*i + 1]], topn=1)[0][0] == test[4*i]:
            c12 = c12 + 1                
    except KeyError:
        erros = erros + 1                   
        
print t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12

# %%
f.write(t)
f.write(' ')
f.write(erros)
f.write(' ')
f.write(c1)
f.write(' ')
f.write(c2)
f.write(' ')
f.write(c3)
f.write(' ')
f.write(c4)
f.write(' ')
f.write(c5)
f.write(' ')
f.write(c6)
f.write(' ')
f.write(c7)
f.write(' ')
f.write(c8)
f.write(' ')
f.write(c9)
f.write(' ')
f.write(c10)
f.write(' ')
f.write(c11)
f.write(' ')
f.write(c12)

f.write('\n')
f.write('porcentual de acertos')
f.write('\n')
f.write(c1/t)
f.write(' ')
f.write(c2/t)
f.write(' ')
f.write(c3/t)
f.write(' ')
f.write(c4/t)
f.write(' ')
f.write(c5/t)
f.write(' ')
f.write(c6/t)
f.write(' ')
f.write(c7/t)
f.write(' ')
f.write(c8/t)
f.write(' ')
f.write(c9/t)
f.write(' ')
f.write(c10/t)
f.write(' ')
f.write(c11/t)
f.write(' ')
f.write(c12/t)
f.write('\n')

# %%
#t, erros, c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12
val = [1056, 0, 0, 0, 88, 88, 472, 418, 418, 472, 57, 57, 0, 0]

# %%
float(val[1])/val[0]
# Out:
# 0.5715725806451613

# %%
for i in range(13):
    print float(val[i+1])/val[0] *100
# Out:
# 0.0
# 0.0
# 0.0
# 8.33333333333
# 8.33333333333
# 44.696969697
# 39.5833333333
# 39.5833333333
# 44.696969697
# 5.39772727273
# 5.39772727273
# 0.0
# 0.0
