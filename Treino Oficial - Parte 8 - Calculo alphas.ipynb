# %%
import gensim
import codecs
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

path = ''

# %%
modelen = gensim.models.Word2Vec.load(path + 'model-english')
modelpt = gensim.models.Word2Vec.load(path + 'model-portuguese')

h = codecs.open(path + 'on_model_en.txt', encoding = 'utf-8', mode = 'r')
i = codecs.open(path + 'on_model_pt.txt', encoding = 'utf-8', mode = 'r')

words_en = h.read().split()
words_pt = i.read().split()

# %% [raw]
# Teste: Cálculo dos erros - Soma dos quadrados dos erros (pivos - traduções)

# %% [raw]
# Calcular W1 e W3

# %%
W1 = (0.00001)*np.random.random_sample((100,100))
W2 = (0.00001)*np.random.random_sample((100,100))
W3 = (0.00001)*np.random.random_sample((100,100))
W4 = (0.00001)*np.random.random_sample((100,100))
W5 = (0.00001)*np.random.random_sample((100,100))
W6 = (0.00001)*np.random.random_sample((100,100))
W7 = (0.00001)*np.random.random_sample((100,100))
W8 = (0.00001)*np.random.random_sample((100,100))
W9 = (0.00001)*np.random.random_sample((100,100))
W10 = (0.00001)*np.random.random_sample((100,100))
W11 = (0.00001)*np.random.random_sample((100,100))
W12 = (0.00001)*np.random.random_sample((100,100))
W13 = (0.00001)*np.random.random_sample((100,100))
W14 = (0.00001)*np.random.random_sample((100,100))
W15 = (0.00001)*np.random.random_sample((100,100))
W16 = (0.00001)*np.random.random_sample((100,100))
W17 = (0.00001)*np.random.random_sample((100,100))


erro1 = np.zeros(4811)
erro2 = np.zeros(4811)
erro3 = np.zeros(4811)
erro4 = np.zeros(4811)
erro5 = np.zeros(4811)
erro6 = np.zeros(4811)
erro7 = np.zeros(4811)
erro8 = np.zeros(4811)
erro9 = np.zeros(4811)
erro10 = np.zeros(4811)
erro11 = np.zeros(4811)
erro12 = np.zeros(4811)
erro13 = np.zeros(4811)
erro14 = np.zeros(4811)
erro15 = np.zeros(4811)
erro16 = np.zeros(4811)
erro17 = np.zeros(4811)


for k in range(3311):
    X = modelpt[words_pt[k]]
    y = modelen[words_en[k]]
    
    #X é o vetor input, yo é o calculado e y é o output esperado
    
    y1 = np.dot(X,W1)
    y2 = np.dot(X,W2)
    y3 = np.dot(X,W3)
    y4 = np.dot(X,W4)
    y5 = np.dot(X,W5)
    y6 = np.dot(X,W6)
    y7 = np.dot(X,W7)
    y8 = np.dot(X,W8)
    y9 = np.dot(X,W9)
    y10 = np.dot(X,W10)
    y11 = np.dot(X,W11)
    y12 = np.dot(X,W12)
    y13 = np.dot(X,W13)
    y14 = np.dot(X,W14)
    y15 = np.dot(X,W15)
    y16 = np.dot(X,W16)
    y17 = np.dot(X,W17)
    
    dif1 = y - y1
    dif2 = y - y2
    dif3 = y - y3
    dif4 = y - y4
    dif5 = y - y5
    dif6 = y - y6
    dif7 = y - y7
    dif8 = y - y8
    dif9 = y - y9
    dif10 = y - y10
    dif11 = y - y11
    dif12 = y - y12
    dif13 = y - y13
    dif14 = y - y14
    dif15 = y - y15
    dif16 = y - y16
    dif17 = y - y17
    
    djdw1 = np.dot(np.transpose(X),dif1)
    djdw2 = np.dot(np.transpose(X),dif2)
    djdw3 = np.dot(np.transpose(X),dif3)
    djdw4 = np.dot(np.transpose(X),dif4)
    djdw5 = np.dot(np.transpose(X),dif5)
    djdw6 = np.dot(np.transpose(X),dif6)
    djdw7 = np.dot(np.transpose(X),dif7)
    djdw8 = np.dot(np.transpose(X),dif8)
    djdw9 = np.dot(np.transpose(X),dif9)
    djdw10 = np.dot(np.transpose(X),dif10)
    djdw11 = np.dot(np.transpose(X),dif11)
    djdw12 = np.dot(np.transpose(X),dif12)
    djdw13 = np.dot(np.transpose(X),dif13)
    djdw14 = np.dot(np.transpose(X),dif14)
    djdw15 = np.dot(np.transpose(X),dif15)    
    djdw16 = np.dot(np.transpose(X),dif16)
    djdw17 = np.dot(np.transpose(X),dif17)
    
            
        
    W1 = W1 - djdw1*10**(-6)
    W2 = W2 - djdw2*10**(-7)
    W3 = W3 - djdw3*10**(-8)
    W4 = W4 - djdw4*10**(-9)
    W5 = W5 - djdw5*10**(-10)
    W6 = W6 - djdw6*10**(-11)
    W7 = W7 - djdw7*10**(-12)
    W8 = W8 - djdw8*10**(-13)
    W9 = W9 - djdw9*10**(-14)
    W10 = W10 - djdw10*10**(-15)
    W11 = W11 - djdw11*10**(-16)
    W12 = W12 - djdw12*10**(-17)
    W13 = W13 - djdw13*10**(-1)
    W14 = W14 - djdw14*10**(-2)
    W15 = W15 - djdw15*10**(-3)
    W16 = W16 - djdw16*10**(-4)
    W17 = W17 - djdw17*10**(-5)

# %%
for i in range(4811):
    X = modelpt[words_pt[i]]
    y = modelen[words_en[i]]
    
    z1 = np.dot(X,W1)
    z2 = np.dot(X,W2)
    z3 = np.dot(X,W3)
    z4 = np.dot(X,W4)
    z5 = np.dot(X,W5)
    z6 = np.dot(X,W6)
    z7 = np.dot(X,W7)
    z8 = np.dot(X,W8)
    z9 = np.dot(X,W9)
    z10 = np.dot(X,W10)
    z11 = np.dot(X,W11)
    z12 = np.dot(X,W12)
    z13 = np.dot(X,W13)
    z14 = np.dot(X,W14)
    z15 = np.dot(X,W15)
    z16 = np.dot(X,W16)
    z17 = np.dot(X,W17)
    
    erro1[i] = (np.linalg.norm(y - z1))/np.linalg.norm(y)
    erro2[i] = (np.linalg.norm(y - z2))/np.linalg.norm(y)
    erro3[i] = (np.linalg.norm(y - z3))/np.linalg.norm(y)
    erro4[i] = (np.linalg.norm(y - z4))/np.linalg.norm(y)
    erro5[i] = (np.linalg.norm(y - z5))/np.linalg.norm(y)
    erro6[i] = (np.linalg.norm(y - z6))/np.linalg.norm(y)
    erro7[i] = (np.linalg.norm(y - z7))/np.linalg.norm(y)
    erro8[i] = (np.linalg.norm(y - z8))/np.linalg.norm(y)
    erro9[i] = (np.linalg.norm(y - z9))/np.linalg.norm(y)
    erro10[i] = (np.linalg.norm(y - z10))/np.linalg.norm(y)
    erro11[i] = (np.linalg.norm(y - z11))/np.linalg.norm(y)
    erro12[i] = (np.linalg.norm(y - z12))/np.linalg.norm(y)
    erro13[i] = (np.linalg.norm(y - z13))/np.linalg.norm(y)
    erro14[i] = (np.linalg.norm(y - z14))/np.linalg.norm(y)
    erro15[i] = (np.linalg.norm(y - z15))/np.linalg.norm(y)
    erro16[i] = (np.linalg.norm(y - z16))/np.linalg.norm(y)
    erro17[i] = (np.linalg.norm(y - z17))/np.linalg.norm(y)

    
soma1 = 0
soma2 = 0
soma3 = 0
soma4 = 0
soma5 = 0
soma6 = 0
soma7 = 0
soma8 = 0
soma9 = 0
soma10 = 0
soma11 = 0
soma12 = 0
soma13 = 0
soma14 = 0
soma15 = 0
soma16 = 0
soma17 = 0

for j in range(len(erro1)):
    soma1 = soma1 + erro1[j]
    soma2 = soma2 + erro2[j]
    soma3 = soma3 + erro3[j]
    soma4 = soma4 + erro4[j]
    soma5 = soma5 + erro5[j]
    soma6 = soma6 + erro6[j]
    soma7 = soma7 + erro7[j]
    soma8 = soma8 + erro8[j]
    soma9 = soma9 + erro9[j]
    soma10 = soma10 + erro10[j]
    soma11 = soma11 + erro11[j]
    soma12 = soma12 + erro12[j]
    soma13 = soma13 + erro13[j]
    soma14 = soma14 + erro14[j]
    soma15 = soma15 + erro15[j]
    soma16 = soma16 + erro16[j]
    soma17 = soma17 + erro17[j]

    
minimo = min(soma1, soma2, soma3, soma4, soma5, soma6, soma7, soma8, soma9, soma10, soma11, soma12, soma13, soma14, soma15, 
             soma16, soma17)    
maximo = max(soma1, soma2, soma3, soma4, soma5, soma6, soma7, soma8, soma9, soma10, soma11, soma12, soma13, soma14, soma15,
             soma16, soma17)    
print minimo, maximo
print soma1, soma2, soma3, soma4, soma5, soma6, soma7, soma8, soma9, soma10, soma11, soma12, soma13, soma14, soma15, soma16, 
soma17
#9
# Out:
# 4810.95444216 2.37233540938e+88
# 4810.9962427 4811.00038185 4811.00180962 4811.00122792 4810.99951571 4810.99974688 4811.00167309 4811.00067462 4810.99919996 4811.00063269 4810.99992567 4811.003216 nan 2.37233540938e+88 380960784650.0 4926.02714968
# 4810.9544421627825

# %%
print W1
# Out:
# [[ -3.89307974e-06  -3.08696689e-06  -7.73745600e-06 ...,  -3.77382068e-06
#    -6.51748557e-06  -1.02798022e-05]
#  [ -5.64858699e-06  -6.73595060e-06  -9.88301867e-06 ...,  -2.95799787e-06
#    -3.47181538e-06  -7.65100778e-06]
#  [ -1.75112296e-06  -6.52130135e-06  -7.20584833e-06 ...,  -1.44759750e-06
#    -7.93463306e-06  -4.88751029e-06]
#  ...,
#  [ -3.00265912e-06  -2.31317883e-06  -4.96550809e-06 ...,  -2.84455861e-06
#    -1.04702386e-05  -3.98246686e-06]
#  [ -1.79324709e-06  -7.67303917e-06  -1.08747745e-05 ...,  -6.09359383e-06
#    -4.79075502e-06  -3.01150057e-06]
#  [ -3.17088442e-06  -5.16756864e-06  -5.68554049e-06 ...,  -9.98043756e-06
#    -1.54008549e-06  -4.71495312e-06]]

# %%
#Erros de W1 para cada valor de alpha

plt.plot(1, soma1, 'ro')
plt.plot(2, soma2, 'bo')
plt.plot(3, soma3, 'co')
plt.plot(4, soma4, 'ro')
plt.plot(5, soma5, 'bo')
plt.plot(6, soma6, 'co')
plt.plot(7, soma7, 'ro')
plt.plot(8, soma8, 'bo')
plt.plot(9, soma9, 'co')
plt.plot(10, soma10, 'ro')
plt.plot(11, soma11, 'bo')
plt.plot(12, soma12, 'co')

plt.legend(loc='upper right')
plt.axis([0, 13, 29200, 50000])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9c9581b73779> in <module>()
#       1 #Erros de W1 para cada valor de alpha
#       2
# ----> 3 plt.plot(1, soma1, 'ro')
#       4 plt.plot(2, soma2, 'bo')
#       5 plt.plot(3, soma3, 'co')
#
# NameError: name 'soma1' is not defined

# %%
#W3 oficial

W1 = np.random.rand(100,100)
djdw1 = np.random.rand(100,100)

W2 = np.random.rand(100,100)
djdw2 = np.random.rand(100,100)

W3 = np.random.rand(100,100)
djdw3 = np.random.rand(100,100)

W4 = np.random.rand(100,100)
djdw4 = np.random.rand(100,100)

W5 = np.random.rand(100,100)
djdw5 = np.random.rand(100,100)

W6 = np.random.rand(100,100)
djdw6 = np.random.rand(100,100)

W7 = np.random.rand(100,100)
djdw7 = np.random.rand(100,100)

W8 = np.random.rand(100,100)
djdw8 = np.random.rand(100,100)

W9 = np.random.rand(100,100)
djdw9 = np.random.rand(100,100)

W10 = np.random.rand(100,100)
djdw10 = np.random.rand(100,100)

W11 = np.random.rand(100,100)
djdw11 = np.random.rand(100,100)

W12 = np.random.rand(100,100)
djdw12 = np.random.rand(100,100)


erro1 = np.zeros(4811)
erro2 = np.zeros(4811)
erro3 = np.zeros(4811)
erro4 = np.zeros(4811)
erro5 = np.zeros(4811)
erro6 = np.zeros(4811)
erro7 = np.zeros(4811)
erro8 = np.zeros(4811)
erro9 = np.zeros(4811)
erro10 = np.zeros(4811)
erro11 = np.zeros(4811)
erro12 = np.zeros(4811)

for k in range(3311):
    X = modelpt[words_pt[k]]
    y = modelen[words_en[k]]
    
    z1 = np.dot(X,W1)
    z2 = np.dot(X,W2)
    z3 = np.dot(X,W3)
    z4 = np.dot(X,W4)
    z5 = np.dot(X,W5)
    z6 = np.dot(X,W6)
    z7 = np.dot(X,W7)
    z8 = np.dot(X,W8)
    z9 = np.dot(X,W9)
    z10 = np.dot(X,W10)
    z11 = np.dot(X,W11)
    z12 = np.dot(X,W12)
    
    y1 = 1/(1+np.exp(-z1)) #função sigmoide
    sigd1 = np.exp(-z1)/((1+np.exp(-z1))**2) #derivada da função sigmoide
    
    y2 = 1/(1+np.exp(-z2)) #função sigmoide
    sigd2 = np.exp(-z2)/((1+np.exp(-z2))**2) #derivada da função sigmoide
    
    y3 = 1/(1+np.exp(-z3)) #função sigmoide
    sigd3 = np.exp(-z3)/((1+np.exp(-z3))**2) #derivada da função sigmoide
    
    y4 = 1/(1+np.exp(-z4)) #função sigmoide
    sigd4 = np.exp(-z4)/((1+np.exp(-z4))**2) #derivada da função sigmoide
    
    y5 = 1/(1+np.exp(-z5)) #função sigmoide
    sigd5 = np.exp(-z5)/((1+np.exp(-z5))**2) #derivada da função sigmoide
    
    y6 = 1/(1+np.exp(-z6)) #função sigmoide
    sigd6 = np.exp(-z6)/((1+np.exp(-z6))**2) #derivada da função sigmoide
    
    y7 = 1/(1+np.exp(-z7)) #função sigmoide
    sigd7 = np.exp(-z7)/((1+np.exp(-z7))**2) #derivada da função sigmoide
    
    y8 = 1/(1+np.exp(-z8)) #função sigmoide
    sigd8 = np.exp(-z8)/((1+np.exp(-z8))**2) #derivada da função sigmoide
    
    y9 = 1/(1+np.exp(-z9)) #função sigmoide
    sigd9 = np.exp(-z9)/((1+np.exp(-z9))**2) #derivada da função sigmoide
    
    y10 = 1/(1+np.exp(-z10)) #função sigmoide
    sigd10 = np.exp(-z10)/((1+np.exp(-z10))**2) #derivada da função sigmoide
    
    y11 = 1/(1+np.exp(-z11)) #função sigmoide
    sigd11 = np.exp(-z11)/((1+np.exp(-z11))**2) #derivada da função sigmoide
    
    y12 = 1/(1+np.exp(-z12)) #função sigmoide
    sigd12 = np.exp(-z12)/((1+np.exp(-z12))**2) #derivada da função sigmoide
    
    
    
    
    for a in range(100):
        for b in range(100):
            djdw1[a][b] = (y[b]-y1[b])*sigd1[b]*X[a]
            djdw2[a][b] = (y[b]-y2[b])*sigd2[b]*X[a]
            djdw3[a][b] = (y[b]-y3[b])*sigd3[b]*X[a]
            djdw4[a][b] = (y[b]-y4[b])*sigd4[b]*X[a]
            djdw5[a][b] = (y[b]-y5[b])*sigd5[b]*X[a]
            djdw6[a][b] = (y[b]-y6[b])*sigd6[b]*X[a]
            djdw7[a][b] = (y[b]-y7[b])*sigd7[b]*X[a]
            djdw8[a][b] = (y[b]-y8[b])*sigd8[b]*X[a]
            djdw9[a][b] = (y[b]-y9[b])*sigd9[b]*X[a]
            djdw10[a][b] = (y[b]-y10[b])*sigd10[b]*X[a]
            djdw11[a][b] = (y[b]-y11[b])*sigd11[b]*X[a]
            djdw12[a][b] = (y[b]-y12[b])*sigd12[b]*X[a]
            
    W1 = W1 - djdw1*0.01
    W2 = W2 - djdw2*0.001
    W3 = W3 - djdw3*0.0001
    W4 = W4 - djdw4*0.00001
    W5 = W5 - djdw5*0.000001
    W6 = W6 - djdw6*0.0000001
    W7 = W7 - djdw7*0.00000001
    W8 = W8 - djdw8*0.000000001
    W9 = W9 - djdw9*0.0000000001
    W10 = W10 - djdw10*0.00000000001
    W11 = W11 - djdw11*0.000000000001
    W12 = W12 - djdw12*0.0000000000001

# %%
for i in range(4811):
    X = modelpt[words_pt[i]]
    y = modelen[words_en[i]]
    
    z1 = np.dot(X,W1)
    z2 = np.dot(X,W2)
    z3 = np.dot(X,W3)
    z4 = np.dot(X,W4)
    z5 = np.dot(X,W5)
    z6 = np.dot(X,W6)
    z7 = np.dot(X,W7)
    z8 = np.dot(X,W8)
    z9 = np.dot(X,W9)
    z10 = np.dot(X,W10)
    z11 = np.dot(X,W11)
    z12 = np.dot(X,W12)
    
    erro1[i] = (np.linalg.norm(y - z1))**2
    erro2[i] = (np.linalg.norm(y - z2))**2
    erro3[i] = (np.linalg.norm(y - z3))**2
    erro4[i] = (np.linalg.norm(y - z4))**2
    erro5[i] = (np.linalg.norm(y - z5))**2
    erro6[i] = (np.linalg.norm(y - z6))**2
    erro7[i] = (np.linalg.norm(y - z7))**2
    erro8[i] = (np.linalg.norm(y - z8))**2
    erro9[i] = (np.linalg.norm(y - z9))**2
    erro10[i] = (np.linalg.norm(y - z10))**2
    erro11[i] = (np.linalg.norm(y - z11))**2
    erro12[i] = (np.linalg.norm(y - z12))**2
    
soma1 = 0
soma2 = 0
soma3 = 0
soma4 = 0
soma5 = 0
soma6 = 0
soma7 = 0
soma8 = 0
soma9 = 0
soma10 = 0
soma11 = 0
soma12 = 0

for j in range(len(erro1)):
    soma1 = soma1 + erro1[j]
    soma2 = soma2 + erro2[j]
    soma3 = soma3 + erro3[j]
    soma4 = soma4 + erro4[j]
    soma5 = soma5 + erro5[j]
    soma6 = soma6 + erro6[j]
    soma7 = soma7 + erro7[j]
    soma8 = soma8 + erro8[j]
    soma9 = soma9 + erro9[j]
    soma10 = soma10 + erro10[j]
    soma11 = soma11 + erro11[j]
    soma12 = soma12 + erro12[j]

minimo = min(soma1, soma2, soma3, soma4, soma5, soma6, soma7, soma8, soma9, soma10, soma11, soma12)    
maximo = max(soma1, soma2, soma3, soma4, soma5, soma6, soma7, soma8, soma9, soma10, soma11, soma12)    
print soma1, soma2, soma3, soma4, soma5, soma6, soma7, soma8, soma9, soma10, soma11, soma12
print minimo, maximo
#9

# %%
#grafico
#Erros de W3 para cada valor de alpha

plt.plot(1, soma1, 'ro')
plt.plot(2, soma2, 'bo')
plt.plot(3, soma3, 'co')
plt.plot(4, soma4, 'ro')
plt.plot(5, soma5, 'bo')
plt.plot(6, soma6, 'co')
plt.plot(7, soma7, 'ro')
plt.plot(8, soma8, 'bo')
plt.plot(9, soma9, 'co')
plt.plot(10, soma10, 'ro')
plt.plot(11, soma11, 'bo')
plt.plot(12, soma12, 'co')

plt.legend(loc='upper right')
plt.axis([0, 13, 1087173., 1140000])
plt.show()

# %% [raw]
# Calcular W2 e W4

# %%
#Sem sigmoide e com repetição

W21 = np.random.rand(100,100)
djdw21 = np.random.rand(100,100)

W22 = np.random.rand(100,100)
djdw22 = np.random.rand(100,100)

W23 = np.random.rand(100,100)
djdw23 = np.random.rand(100,100)

W24 = np.random.rand(100,100)
djdw24 = np.random.rand(100,100)

W25 = np.random.rand(100,100)
djdw25 = np.random.rand(100,100)

W26 = np.random.rand(100,100)
djdw26 = np.random.rand(100,100)

W27 = np.random.rand(100,100)
djdw27 = np.random.rand(100,100)

W28 = np.random.rand(100,100)
djdw28 = np.random.rand(100,100)

W29 = np.random.rand(100,100)
djdw29 = np.random.rand(100,100)

W210 = np.random.rand(100,100)
djdw210 = np.random.rand(100,100)

W211 = np.random.rand(100,100)
djdw211 = np.random.rand(100,100)

W212 = np.random.rand(100,100)
djdw212 = np.random.rand(100,100)


W41 = np.random.rand(100,100)
djdw41 = np.random.rand(100,100)

W42 = np.random.rand(100,100)
djdw42 = np.random.rand(100,100)

W43 = np.random.rand(100,100)
djdw43 = np.random.rand(100,100)

W44 = np.random.rand(100,100)
djdw44 = np.random.rand(100,100)

W45 = np.random.rand(100,100)
djdw45 = np.random.rand(100,100)

W46 = np.random.rand(100,100)
djdw46 = np.random.rand(100,100)

W47 = np.random.rand(100,100)
djdw47 = np.random.rand(100,100)

W48 = np.random.rand(100,100)
djdw48 = np.random.rand(100,100)

W49 = np.random.rand(100,100)
djdw49 = np.random.rand(100,100)

W410 = np.random.rand(100,100)
djdw410 = np.random.rand(100,100)

W411 = np.random.rand(100,100)
djdw411 = np.random.rand(100,100)

W412 = np.random.rand(100,100)
djdw412 = np.random.rand(100,100)

for k in range(3311):
    X = modelpt[words_pt[k]]
    y = modelen[words_en[k]]
    for i in range(15):    
        y21 = np.dot(X,W21)
        y22 = np.dot(X,W22)
        y23 = np.dot(X,W23)
        y24 = np.dot(X,W24)
        y25 = np.dot(X,W25)
        y26 = np.dot(X,W26)
        y27 = np.dot(X,W27)
        y28 = np.dot(X,W28)
        y29 = np.dot(X,W29)
        y210 = np.dot(X,W210)
        y211 = np.dot(X,W211)
        y212 = np.dot(X,W212)
        
        z1 = np.dot(X,W41)
        z2 = np.dot(X,W42)
        z3 = np.dot(X,W43)
        z4 = np.dot(X,W44)
        z5 = np.dot(X,W45)
        z6 = np.dot(X,W46)
        z7 = np.dot(X,W47)
        z8 = np.dot(X,W48)
        z9 = np.dot(X,W49)
        z10 = np.dot(X,W410)
        z11 = np.dot(X,W411)
        z12 = np.dot(X,W412)
    
        y41 = 1/(1+np.exp(-z1)) #função sigmoide
        sigd1 = np.exp(-z1)/((1+np.exp(-z1))**2) #derivada da função sigmoide
    
        y42 = 1/(1+np.exp(-z2)) #função sigmoide
        sigd2 = np.exp(-z2)/((1+np.exp(-z2))**2) #derivada da função sigmoide
    
        y43 = 1/(1+np.exp(-z3)) #função sigmoide
        sigd3 = np.exp(-z3)/((1+np.exp(-z3))**2) #derivada da função sigmoide
    
        y44 = 1/(1+np.exp(-z4)) #função sigmoide
        sigd4 = np.exp(-z4)/((1+np.exp(-z4))**2) #derivada da função sigmoide
    
        y45 = 1/(1+np.exp(-z5)) #função sigmoide
        sigd5 = np.exp(-z5)/((1+np.exp(-z5))**2) #derivada da função sigmoide
    
        y46 = 1/(1+np.exp(-z6)) #função sigmoide
        sigd6 = np.exp(-z6)/((1+np.exp(-z6))**2) #derivada da função sigmoide
    
        y47 = 1/(1+np.exp(-z7)) #função sigmoide
        sigd7 = np.exp(-z7)/((1+np.exp(-z7))**2) #derivada da função sigmoide
    
        y48 = 1/(1+np.exp(-z8)) #função sigmoide
        sigd8 = np.exp(-z8)/((1+np.exp(-z8))**2) #derivada da função sigmoide
    
        y49 = 1/(1+np.exp(-z9)) #função sigmoide
        sigd9 = np.exp(-z9)/((1+np.exp(-z9))**2) #derivada da função sigmoide
    
        y410 = 1/(1+np.exp(-z10)) #função sigmoide
        sigd10 = np.exp(-z10)/((1+np.exp(-z10))**2) #derivada da função sigmoide
    
        y411 = 1/(1+np.exp(-z11)) #função sigmoide
        sigd11 = np.exp(-z11)/((1+np.exp(-z11))**2) #derivada da função sigmoide
    
        y412 = 1/(1+np.exp(-z12)) #função sigmoide
        sigd12 = np.exp(-z12)/((1+np.exp(-z12))**2) #derivada da função sigmoide
        
        for a in range(100):
            for b in range(100):
                djdw21[a][b] = (y[b]-y21[b])*X[a]
                djdw22[a][b] = (y[b]-y22[b])*X[a]
                djdw23[a][b] = (y[b]-y23[b])*X[a]
                djdw24[a][b] = (y[b]-y24[b])*X[a]
                djdw25[a][b] = (y[b]-y25[b])*X[a]
                djdw26[a][b] = (y[b]-y26[b])*X[a]
                djdw27[a][b] = (y[b]-y27[b])*X[a]
                djdw28[a][b] = (y[b]-y28[b])*X[a]
                djdw29[a][b] = (y[b]-y29[b])*X[a]
                djdw210[a][b] = (y[b]-y210[b])*X[a]
                djdw211[a][b] = (y[b]-y211[b])*X[a]
                djdw212[a][b] = (y[b]-y212[b])*X[a]
                
                djdw41[a][b] = (y[b]-y41[b])*sigd1[b]*X[a]
                djdw42[a][b] = (y[b]-y42[b])*sigd2[b]*X[a]
                djdw43[a][b] = (y[b]-y43[b])*sigd3[b]*X[a]
                djdw44[a][b] = (y[b]-y44[b])*sigd4[b]*X[a]
                djdw45[a][b] = (y[b]-y45[b])*sigd5[b]*X[a]
                djdw46[a][b] = (y[b]-y46[b])*sigd6[b]*X[a]
                djdw47[a][b] = (y[b]-y47[b])*sigd7[b]*X[a]
                djdw48[a][b] = (y[b]-y48[b])*sigd8[b]*X[a]
                djdw49[a][b] = (y[b]-y49[b])*sigd9[b]*X[a]
                djdw410[a][b] = (y[b]-y410[b])*sigd10[b]*X[a]
                djdw411[a][b] = (y[b]-y411[b])*sigd11[b]*X[a]
                djdw412[a][b] = (y[b]-y412[b])*sigd12[b]*X[a]
              
                                
                
        W21 = W21 - djdw21*0.000001
        W22 = W22 - djdw22*0.0000001
        W23 = W23 - djdw23*0.00000001
        W24 = W24 - djdw24*0.000000001
        W25 = W25 - djdw25*0.0000000001
        W26 = W26 - djdw26*0.00000000001
        W27 = W27 - djdw27*0.000000000001
        W28 = W28 - djdw28*0.0000000000001
        W29 = W29 - djdw29*0.00000000000001
        W210 = W210 - djdw210*0.00000000000001
        W211 = W211 - djdw211*0.000000000000001
        W212 = W212 - djdw212*0.0000000000000001
        
        W41 = W41 - djdw41*0.000001
        W42 = W42 - djdw42*0.0000001
        W43 = W43 - djdw43*0.00000001
        W44 = W44 - djdw44*0.000000001
        W45 = W45 - djdw45*0.0000000001
        W46 = W46 - djdw46*0.00000000001
        W47 = W47 - djdw47*0.000000000001
        W48 = W48 - djdw48*0.0000000000001
        W49 = W49 - djdw49*0.00000000000001
        W410 = W410 - djdw410*0.00000000000001
        W411 = W411 - djdw411*0.000000000000001
        W412 = W412 - djdw412*0.0000000000000001
#X = np.array([1,5,7])[np.newaxis]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-c56886cc165a> in <module>()
#     144             for b in range(100):
#     145                 djdw21[a][b] = (y[b]-y21[b])*X[a]
# --> 146                 djdw22[a][b] = (y[b]-y22[b])*X[a]
#     147                 djdw23[a][b] = (y[b]-y23[b])*X[a]
#     148                 djdw24[a][b] = (y[b]-y24[b])*X[a]
#
# KeyboardInterrupt:

# %%
for i in range(4811):
    X = modelpt[words_pt[i]]
    y = modelen[words_en[i]]
    
    z21 = np.dot(X,W21)
    z22 = np.dot(X,W22)
    z23 = np.dot(X,W23)
    z24 = np.dot(X,W24)
    z25 = np.dot(X,W25)
    z26 = np.dot(X,W26)
    z27 = np.dot(X,W27)
    z28 = np.dot(X,W28)
    z29 = np.dot(X,W29)
    z210 = np.dot(X,W210)
    z211 = np.dot(X,W211)
    z212 = np.dot(X,W212)
    
    z41 = np.dot(X,W41)
    z42 = np.dot(X,W42)
    z43 = np.dot(X,W43)
    z44 = np.dot(X,W44)
    z45 = np.dot(X,W45)
    z46 = np.dot(X,W46)
    z47 = np.dot(X,W47)
    z48 = np.dot(X,W48)
    z49 = np.dot(X,W49)
    z410 = np.dot(X,W410)
    z411 = np.dot(X,W411)
    z412 = np.dot(X,W412)
    
    erro21[i] = (np.linalg.norm(y - z21))/np.linalg.norm(y)
    erro22[i] = (np.linalg.norm(y - z22))/np.linalg.norm(y)
    erro23[i] = (np.linalg.norm(y - z23))/np.linalg.norm(y)
    erro24[i] = (np.linalg.norm(y - z24))/np.linalg.norm(y)
    erro25[i] = (np.linalg.norm(y - z25))/np.linalg.norm(y)
    erro26[i] = (np.linalg.norm(y - z26))/np.linalg.norm(y)
    erro27[i] = (np.linalg.norm(y - z27))/np.linalg.norm(y)
    erro28[i] = (np.linalg.norm(y - z28))/np.linalg.norm(y)
    erro29[i] = (np.linalg.norm(y - z29))/np.linalg.norm(y)
    erro210[i] = (np.linalg.norm(y - z210))/np.linalg.norm(y)
    erro211[i] = (np.linalg.norm(y - z211))/np.linalg.norm(y)
    erro212[i] = (np.linalg.norm(y - z212))/np.linalg.norm(y)
    
    erro41[i] = (np.linalg.norm(y - z41))/np.linalg.norm(y)
    erro42[i] = (np.linalg.norm(y - z42))/np.linalg.norm(y)
    erro43[i] = (np.linalg.norm(y - z43))/np.linalg.norm(y)
    erro44[i] = (np.linalg.norm(y - z44))/np.linalg.norm(y)
    erro45[i] = (np.linalg.norm(y - z45))/np.linalg.norm(y)
    erro46[i] = (np.linalg.norm(y - z46))/np.linalg.norm(y)
    erro47[i] = (np.linalg.norm(y - z47))/np.linalg.norm(y)
    erro48[i] = (np.linalg.norm(y - z48))/np.linalg.norm(y)
    erro49[i] = (np.linalg.norm(y - z49))/np.linalg.norm(y)
    erro410[i] = (np.linalg.norm(y - z410))/np.linalg.norm(y)
    erro411[i] = (np.linalg.norm(y - z411))/np.linalg.norm(y)
    erro412[i] = (np.linalg.norm(y - z412))/np.linalg.norm(y)
    
soma21 = 0
soma22 = 0
soma23 = 0
soma24 = 0
soma25 = 0
soma26 = 0
soma27 = 0
soma28 = 0
soma29 = 0
soma210 = 0
soma211 = 0
soma212 = 0

soma41 = 0
soma42 = 0
soma43 = 0
soma44 = 0
soma45 = 0
soma46 = 0
soma47 = 0
soma48 = 0
soma49 = 0
soma410 = 0
soma411 = 0
soma412 = 0

for j in range(len(erro1)):
    soma21 = soma21 + erro21[j]
    soma22 = soma22 + erro22[j]
    soma23 = soma23 + erro23[j]
    soma24 = soma24 + erro24[j]
    soma25 = soma25 + erro25[j]
    soma26 = soma26 + erro26[j]
    soma27 = soma27 + erro27[j]
    soma28 = soma28 + erro28[j]
    soma29 = soma29 + erro29[j]
    soma210 = soma210 + erro210[j]
    soma211 = soma211 + erro211[j]
    soma212 = soma212 + erro212[j]
    
    soma41 = soma41 + erro41[j]
    soma42 = soma42 + erro42[j]
    soma43 = soma43 + erro43[j]
    soma44 = soma44 + erro44[j]
    soma45 = soma45 + erro45[j]
    soma46 = soma46 + erro46[j]
    soma47 = soma47 + erro47[j]
    soma48 = soma48 + erro48[j]
    soma49 = soma49 + erro49[j]
    soma410 = soma410 + erro410[j]
    soma411 = soma411 + erro411[j]
    soma412 = soma412 + erro412[j]

m1 = min(soma21, soma22, soma23, soma24, soma25, soma26, soma27, soma28, soma29, soma210, soma211, soma212)    
m2 = min(soma41, soma42, soma43, soma44, soma45, soma46, soma47, soma48, soma49, soma410, soma411, soma412)
print soma21, soma22, soma23, soma24, soma25, soma26, soma27, soma28, soma29, soma210, soma211, soma212
print soma41, soma42, soma43, soma44, soma45, soma46, soma47, soma48, soma49, soma410, soma411, soma412
print m1, m2
#8

# %%
alpha1 = 10**(-16)
alpha2 = 10**(-11)
alpha3 = 10**(-11)
alpha4 = 10**(-13)

# %%
soma1 = np.array([[29494.1727352, 29421.3922885, 29373.9932094, 29430.8165962, 29332.5906915, 29521.8327451, 29456.6858236, 
        29337.1980744, 29300.8299161, 29385.5165408, 29126.6285302, 29409.9551461]])

soma2 = np.array([[29651.0236758, 29504.1726331, 29451.2589219, 29444.3325317, 29280.4533634, 29199.8437581, 29451.5050247,
         29619.1477438, 29556.0787752, 29322.2807895, 29368.5380803, 29523.0182816]])

soma3 = np.array([[29267.7595984, 29877.9661702, 29460.1705906, 29649.348886, 29618.0353527, 29265.436037, 29714.9668244,
         29464.2872051, 29719.7415971, 29452.2904481, 29323.4724771, 29526.3954875]])

soma4 = np.array([[29419.4250547, 29452.4412979, 29733.2293985, 29648.0711025, 29343.0056637, 29453.9819743, 29337.5716843,
         29222.1110157, 29525.9707946, 29694.7180717, 29338.7515908, 29531.8814496]])

# %%
l = soma4 * 1/4811
print l
# Out:
# [[ 6.11503327  6.12189593  6.1802597   6.16255895  6.09914896  6.12221617
#    6.09801947  6.07402017  6.13717955  6.17225485  6.09826472  6.13840812]]

# %%
#grafico
#Erros de W3 para cada valor de alpha
# %matplotlib inline
plt.plot(-6, l[0][0], 'ko')
plt.plot(-7, l[0][1], 'ko')
plt.plot(-8, l[0][2], 'ko')
plt.plot(-9, l[0][3], 'ko')
plt.plot(-10, l[0][4], 'ko')
plt.plot(-11, l[0][5], 'ko')
plt.plot(-12, l[0][6], 'ko')
plt.plot(-13, l[0][7], 'ko')
plt.plot(-14, l[0][8], 'ko')
plt.plot(-15, l[0][9], 'ko')
plt.plot(-16, l[0][10], 'ko')
plt.plot(-17, l[0][11], 'ko')

plt.legend(loc='upper right')
plt.axis([-18, -5, 6, 6.3])
plt.show()
